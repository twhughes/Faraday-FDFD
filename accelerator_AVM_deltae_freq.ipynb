# %%
# load plotting library and src files
using PyPlot
include("./src/calcpml_2d.jl");
include("./src/yeeder.jl");
include("./src/fdfd.jl");
include("./src/calc_gradient.jl");

# %%
L = 1;
c0 = 1;
dl = 0.01;
beta = 1;
lam = 2*L*beta;
spc = L/4.0;
src = 0.5*L;
pml = 40*dl;
Pol = "Hz";
BC = [-2,-2];
NPML = [0 0 40 40];
RES = [dl/2 dl/2];

X = lam;
Y = 2*(L+spc+src+src+pml);

Nx = Int(X/dl);
Ny = Int(Y/dl);

Ne = 200;
freq_range = linspace(0.1,1,Ne);
de = 0.001
AVM_s = zeros(Complex64,Ne,1);
D_s = zeros(Ne,1);
G_list = zeros(Ne,1);
phi_list = zeros(Ne,1);

b_init = zeros(Complex64,Nx,Ny);
b_init[:,Int(ceil(Ny/2-spc/dl-L/dl-src/dl))] = 1im;
b_init[:,Int(ceil(Ny/2+spc/dl+L/dl+src/dl))] = -1im ;

MUR2 = ones(Complex64,Nx*2,Ny*2);
ER2 = ones(Complex64,Nx*2,Ny*2);

Ex0 = zeros(Complex64,Nx,Ny);
Ex_aj = zeros(Complex64,Nx,Ny);
eps = zeros(Complex64,Nx,Ny);
delta_device = zeros(Complex64,Nx,Ny);
g = 1;

b=zeros(Complex64,Nx*Ny,1);

# %%
for i in (1:Ne)
    println(i/Ne*100.0);
    lam = 1/(freq_range[i]);
    eps = 4;
    #original calculation    
    println("running original");
    #ER2[Int(Nx-L/dl-1):Int(Nx+L/dl+1),Int(Ny-2*spc/dl-2*L/dl-1):Int(Ny-2*spc/dl+1)] = eps/2;
    #ER2[Int(Nx-L/dl-1):Int(Nx+L/dl+1),Int(Ny+2*spc/dl-1):Int(Ny+2*spc/dl+2*L/dl+1)] = eps/2;    
    ER2[Int(Nx-L/dl):Int(Nx+L/dl),Int(Ny-2*spc/dl-2*L/dl):Int(Ny-2*spc/dl)] = eps;
    ER2[Int(Nx-L/dl):Int(Nx+L/dl),Int(Ny+2*spc/dl):Int(Ny+2*spc/dl+2*L/dl)] = eps;
    
    (Ex0,Ey0,Ez0,Hx0,Hy0,Hz0,eps_struct,DEX,DEY) = fdfd(ER2,MUR2,RES,NPML,BC,lam,Pol,b_init);
    (G,phi) = calc_gradient(Ex0,lam,dl,beta);
    G_list[i] = G;
    phi_list[i] = phi;
    
    #compute adjoint source
    (Nx,Ny) = size(Hz0);
    O = -im*lam/2/pi/c0*spdiagm(1./eps_struct[:])*DEY;
    eta = zeros(Complex64,Nx,Ny);    
    for j = (0:Nx-1)
        eta[j+1,Int(ceil(Ny/2))] = exp(2*pi*im*dl*j/lam/beta);
    end    
    eta = eta[:];
    b = -O*eta;
    
    println("running adjoint");
    (Ex_aj,Ey_aj,Ez_aj,Hx_aj,Hy_aj,Hz_aj,eps_struct,DX,DY) = fdfd(ER2,MUR2,RES,NPML,BC,lam,Pol,b);
    z = Hz_aj[:];
    y = Hz0[:];
    g = transpose(eta)*O*y;
    delta_device = (eps_struct - ones(Nx,Ny))/(eps-1);
    #delta_device = delta_device[:];
    #dAde = -1/eps/eps*((DX*spdiagm(delta_device)*spdiagm(1./eps_struct[:])*DX+DY*spdiagm(delta_device)*spdiagm(1./eps_struct[:])*DY));
    #f = float(-1/lam/beta./abs(g).*real(conj(g).*(transpose(y)*dAde*z)));
    #AVM_s[i] = f[1];
    pcolormesh(real(delta_device),cmap="RdBu")
    f = 1/lam/beta./abs(g).*(conj(g).*(2*pi/lam)^2*dl*dl*(sum(sum(delta_device[20:end-20,20:end-20].*(Ex0[20:end-20,20:end-20].*Ex_aj[20:end-20,20:end-20] + Ey0[20:end-20,20:end-20].*Ey_aj[20:end-20,20:end-20])))));
    AVM_s[i] = f[1];

    println("running direct 1");
    ER2[Int(Nx-L/dl):Int(Nx+L/dl),Int(Ny-2*spc/dl-2*L/dl):Int(Ny-2*spc/dl)] = eps+de;
    ER2[Int(Nx-L/dl):Int(Nx+L/dl),Int(Ny+2*spc/dl):Int(Ny+2*spc/dl+2*L/dl)] = eps+de;    
    (Ex_d1,Ey_d1,Ez_d1,Hx_d1,Hy_d1,Hz_d1,eps_struct,DEY) = fdfd(ER2,MUR2,RES,NPML,BC,lam,Pol,b_init);
    (G1,phi) = calc_gradient(Ex_d1,lam,dl,beta);
    
    println("running direct 2");    
    ER2[Int(Nx-L/dl):Int(Nx+L/dl),Int(Ny-2*spc/dl-2*L/dl):Int(Ny-2*spc/dl)] = eps-de;
    ER2[Int(Nx-L/dl):Int(Nx+L/dl),Int(Ny+2*spc/dl):Int(Ny+2*spc/dl+2*L/dl)] = eps-de;    
    (Ex_d2,Ey_d2,Ez_d2,Hx_d2,Hy_d2,Hz_d2,eps_struct,DEY) = fdfd(ER2,MUR2,RES,NPML,BC,lam,Pol,b_init);
    (G2,phi) = calc_gradient(Ex_d2,lam,dl,beta);
    
    D_s[i] = (G1-G2)/de;

    
    
end
# Out:
# 0.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 1.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 1.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 2.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 2.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 3.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 3.5000000000000004
# running original
# running adjoint
# running direct 1
# running direct 2
# 4.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 4.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 5.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 5.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 6.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 6.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 7.000000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 7.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 8.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 8.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 9.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 9.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 10.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 10.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 11.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 11.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 12.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 12.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 13.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 13.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 14.000000000000002
# running original
# running adjoint
# running direct 1
# running direct 2
# 14.499999999999998
# running original
# running adjoint
# running direct 1
# running direct 2
# 15.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 15.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 16.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 16.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 17.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 17.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 18.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 18.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 19.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 19.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 20.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 20.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 21.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 21.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 22.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 22.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 23.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 23.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 24.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 24.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 25.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 25.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 26.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 26.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 27.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 27.500000000000004
# running original
# running adjoint
# running direct 1
# running direct 2
# 28.000000000000004
# running original
# running adjoint
# running direct 1
# running direct 2
# 28.499999999999996
# running original
# running adjoint
# running direct 1
# running direct 2
# 28.999999999999996
# running original
# running adjoint
# running direct 1
# running direct 2
# 29.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 30.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 30.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 31.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 31.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 32.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 32.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 33.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 33.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 34.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 34.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 35.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 35.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 36.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 36.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 37.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 37.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 38.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 38.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 39.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 39.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 40.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 40.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 41.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 41.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 42.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 42.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 43.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 43.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 44.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 44.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 45.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 45.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 46.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 46.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 47.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 47.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 48.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 48.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 49.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 49.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 50.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 50.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 51.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 51.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 52.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 52.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 53.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 53.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 54.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 54.50000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 55.00000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 55.50000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 56.00000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 56.49999999999999
# running original
# running adjoint
# running direct 1
# running direct 2
# 56.99999999999999
# running original
# running adjoint
# running direct 1
# running direct 2
# 57.49999999999999
# running original
# running adjoint
# running direct 1
# running direct 2
# 57.99999999999999
# running original
# running adjoint
# running direct 1
# running direct 2
# 58.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 59.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 59.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 60.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 60.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 61.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 61.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 62.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 62.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 63.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 63.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 64.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 64.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 65.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 65.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 66.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 66.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 67.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 67.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 68.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 68.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 69.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 69.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 70.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 70.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 71.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 71.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 72.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 72.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 73.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 73.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 74.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 74.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 75.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 75.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 76.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 76.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 77.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 77.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 78.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 78.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 79.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 79.5
# running original
# running adjoint
# running direct 1
# running direct 2
# 80
# LoadError: InterruptException:
# while loading In[8], in expression starting on line 1
#
#  in getindex at /Users/twh/.julia/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/twh/.julia/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/twh/.julia/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/twh/.julia/PyCall/src/conversions.jl:755
#  in convert at /Users/twh/.julia/PyCall/src/conversions.jl:782
#  in pycall at /Users/twh/.julia/PyCall/src/PyCall.jl:363
#  in call at /Users/twh/.julia/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/twh/.julia/PyPlot/src/PyPlot.jl:401

# %%
plot(freq_range,-105*real(AVM_s));
plot(freq_range,D_s);
plot(freq_range,30*G_list)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x321d24d50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x313e18d10>

# %%
#pcolormesh(real(Ex_aj[:,20:end-20]).*real(Ex0[:,20:end-20]).*real(eps[:,20:end-20]),cmap="RdBu")
pcolormesh(real(Ex_aj[:,20:end-20]),cmap="RdBu",vmin=-0.08,vmax=0.08)
colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x326027e50>)
# PyObject <matplotlib.colorbar.Colorbar instance at 0x326687c68>

# %%
xs = dl*(1:Nx);
(a,b) = size(Ex0);
#plot(xs,imag(Ex0[:,Int(b/2)]))
phi = phi_list[1];
println(phi)
plot(xs,real(Ex0[:,int(b/2)]))
plot(xs,real(Ex0[:,Int(b/2)].*exp(im*(2*pi/lam/beta*xs + phi*ones(Nx,1)))))
sum(real(Ex0[:,Int(b/2)].*exp(im*(2*pi/lam/beta*xs + phi*ones(Nx,1)))))

# %%
println(eps_range)
# Out:
# linspace(1

# %%
size(1:20)
# Out:
# (20,)

# %%
AVM_s
# Out:
# 10x1 Array{Complex{Float32},2}:
#             5.8457e-5+0.000121132im
#   2.88867e-5+9.70009e-5im
#   1.56035e-5+7.71818e-5im
#   1.86923e-6+7.55192e-5im
#   -1.2863e-5+7.20296e-5im
#          -0.000178203+0.000229738im
#  -1.94899e-5+8.77637e-5im
#  -4.67039e-5+6.89245e-5im
#  -7.05027e-5+5.32317e-5im
#  -9.52917e-5+2.57729e-5im

# %%
g
# Out:
# LoadError: UndefVarError: g not defined
# while loading In[180], in expression starting on line 1

# %%
pcolormesh(b,cmap="RdBu",vmin=0,vmax=3)
colorbar()
# Out:
# LoadError: PyError (:PyObject_Call) <type 'exceptions.ValueError'>
# ValueError('need more than 1 value to unpack',)
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.py", line 2946, in pcolormesh
#     ret = ax.pcolormesh(*args, **kwargs)
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.py", line 7736, in pcolormesh
#     X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.py", line 7341, in _pcolorargs
#     numRows, numCols = C.shape
#
# while loading In[164], in expression starting on line 1
#
#  in getindex at /Users/twh/.julia/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/twh/.julia/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/twh/.julia/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/twh/.julia/PyCall/src/conversions.jl:755
#  in convert at /Users/twh/.julia/PyCall/src/conversions.jl:782
#  in pycall at /Users/twh/.julia/PyCall/src/PyCall.jl:363
#  in call at /Users/twh/.julia/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/twh/.julia/PyPlot/src/PyPlot.jl:401

# %%
Nx
