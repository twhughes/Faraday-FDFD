# %%
# load plotting library and src files
using PyPlot
include("./src/calcpml_2d.jl");
include("./src/yeeder.jl");
include("./src/fdfd.jl");

# %%
Nf = 100;
freqs = linspace(0.05,0.3,Nf);
#freqs = 0.085;
eps = 11.56;
L = 1;
spc = L/5.0;    
n = 500;
Nx2 = n;             Ny2 = n;
Nx = div(Nx2,2);     Ny = div(Ny2,2);
direct = zeros(Nf,1);
AVM = zeros(Nf,1);
dx = 0.01; dy = 0.01;
RES  = [dx dy];
ER2  = ones(Complex64,Nx2,Ny2);
MUR2 = ones(Complex64,Nx2,Ny2);
NPML = [40 40 40 40];
Pol = "Ez";
Q = zeros(Complex64,Nx,Ny);
BC = [-2,-2];
Is_d = zeros(Complex64,Nf,2);

Direct_s = zeros(Complex64,Nf,1);
AVM_s = zeros(Complex64,Nf,1);

d_eps = 0.01;
eps_vals = [eps-d_eps/2 eps+d_eps/2];
Ez = zeros(Complex64,Nx,Ny);
Ez_AJ = zeros(Complex64,Nx,Ny);

# %%
for fi in (1:Nf)  
    println(fi/Nf*100.0)
    freq = freqs[fi];
    lambda0 = 1/freq;
    
    #original simulation
    println("running original")
    e = eps;
    ER2[Nx-Int(L/dx):Nx+Int(L/dx),Ny-Int(L/dy):Ny+Int(L/dy)] = e;
    Q = zeros(Complex64,Nx,Ny);
    Q[Int(Nx/2)-Int(L/2/dx)-Int(spc/dx),Int(Ny/2)] = 1;
    (Ex,Ey,Ez,Hx,Hy,Hz) = fdfd(ER2,MUR2,RES,NPML,BC,lambda0,Pol,Q);
    E_obs = Ez[Int(Nx/2)+Int(L/2/dx)+Int(spc/dx),Int(Ny/2)];
    
    #adjoint simulation
    println("running adjoint")
    Q = zeros(Complex64,Nx,Ny);    
    Q[Int(Nx/2)+Int(L/2/dx)+Int(spc/dx),Int(Ny/2)] = 2im*conj(E_obs)/freq/2/pi;
    (Ex,Ey,Ez_AJ,Hx,Hy,Hz) = fdfd(ER2,MUR2,RES,NPML,BC,lambda0,Pol,Q);
    
    inner_prod = Ez.*Ez_AJ;
    dT_de = sum(sum(inner_prod[Int(Nx/2)-Int(L/2/dx):Int(Nx/2)+Int(L/2/dx),Int(Ny/2)-Int(L/2/dy):Int(Ny/2)+Int(L/2/dy)]));
    AVM_s[fi] = -dT_de;    
    
    #direct sensitivity
    for ei in (1:2)
        if (ei==1)
            println("running direct 1")
        else
            println("running direct 2")
        end
        e = eps_vals[ei];
        ER2[Nx-Int(L/dx):Nx+Int(L/dx),Ny-Int(L/dy):Ny+Int(L/dy)] = e;
        Q = zeros(Complex64,Nx,Ny);        
        Q[Int(Nx/2)-Int(L/2/dx)-Int(spc/dx),Int(Ny/2)] = 1;
        (Ex,Ey,Ez,Hx,Hy,Hz) = fdfd(ER2,MUR2,RES,NPML,BC,lambda0,Pol,Q);
        I_obs = Hz[Int(Nx/2)+Int(L/2/dx)+Int(spc/dx),Int(Ny/2)];
        Is_d[fi,ei] = abs(I_obs).^2;
    end
    Direct_s[fi] = (Is_d[fi,2]-Is_d[fi,1])/d_eps;
    
end
# Out:
# 1.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 2.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 3.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 4.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 5.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 6.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 7.000000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 8.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 9.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 10.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 11.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 12.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 13.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 14.000000000000002
# running original
# running adjoint
# running direct 1
# running direct 2
# 15.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 16.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 17.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 18.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 19.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 20.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 21.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 22.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 23.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 24.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 25.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 26.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 27.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 28.000000000000004
# running original
# running adjoint
# running direct 1
# running direct 2
# 28.999999999999996
# running original
# running adjoint
# running direct 1
# running direct 2
# 30.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 31.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 32.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 33.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 34.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 35.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 36.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 37.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 38.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 39.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 40.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 41.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 42.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 43.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 44.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 45.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 46.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 47.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 48.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 49.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 50.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 51.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 52.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 53.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 54.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 55.00000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 56.00000000000001
# running original
# running adjoint
# running direct 1
# running direct 2
# 56.99999999999999
# running original
# running adjoint
# running direct 1
# running direct 2
# 57.99999999999999
# running original
# running adjoint
# running direct 1
# running direct 2
# 59.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 60.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 61.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 62.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 63.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 64.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 65.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 66.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 67.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 68.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 69.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 70.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 71.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 72.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 73.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 74.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 75.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 76.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 77.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 78.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 79.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 80.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 81.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 82.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 83.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 84.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 85.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 86.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 87.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 88.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 89.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 90.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 91.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 92.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 93.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 94.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 95.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 96.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 97.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 98.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 99.0
# running original
# running adjoint
# running direct 1
# running direct 2
# 100.0
# running original
# running adjoint
# running direct 1
# running direct 2

# %%
plot(freqs[1:30],imag(AVM_s[1:30]))
plot(freqs[1:30],Direct_s[1:30])
legend(("AVM","Direct"));
xlabel("frequency (c/a)");
ylabel("normalized sensitivity");
# Out:
# /Library/Python/2.7/site-packages/numpy/core/numeric.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ba9a610>)

# %%
#pcolormesh(real(Ez),cmap="RdBu",vmin=-0.0001,vmax=0.0001)
pcolormesh(imag(Ez.*Ez_AJ),cmap="RdBu")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e0aabd0>)
# PyObject <matplotlib.collections.QuadMesh object at 0x31c922710>

# %%
plot(freqs,-imag(AVM_s))
plot(freqs,Direct_s*10000)
legend(("AVM","Direct"));
xlabel("frequency (c/a)");
ylabel("normalized sensitivity");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e63bd90>)

# %%
E_obs = 1-im;
2im*conj(E_obs)
# Out:
# -2 + 2im
